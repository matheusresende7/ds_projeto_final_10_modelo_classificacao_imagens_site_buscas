# %% [markdown]
# # 03. Model VGG

# %% [markdown]
# ### Importando os arquivos do projeto no Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importando as bibliotecas

# %%
import sys
import os
from pathlib import Path
sys.path.append('..')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from IPython.display import Image, display

# %% [markdown]
# ### Configurando para serem exibidas apenas mensagens de erro no Tensor Flow

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # Configurando para serem exibidas apenas mensagens de erro no Tensor Flow

# %% [markdown]
# ### Lendo o dataset

# %%
df = keras.datasets.cifar10 # Armazenando o dataset em uma variável

# %%
(x_train, y_train), (x_test, y_test) = df.load_data() # Armazenando os dados do df já divididos em X e Y de treino e teste
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
class_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck',
] # Definindo uma legenda para as classes

# %% [markdown]
# ### Definindo o modelo Keras a partir de um pipeline

# %%
display(Image('/content/drive/MyDrive/Colab Notebooks/ds_projeto_final_10_modelo_classificacao_imagens_site_buscas/images/VGG.jpg')) # Exibindo a referência VGG

# %%
# Etapa inicial
model = keras.models.Sequential() # Instanciando o modelo

# Etapas de pré processamento
model.add(keras.layers.InputLayer(input_shape=(32, 32, 3))) # Passando o shape dos dados para o modelo
model.add(keras.layers.Rescaling(scale=1./255)) # Fazendo o rescaling dos dados entre 0 e 255 para 0 e 1

# Etapas de data augmentation
model.add(keras.layers.RandomRotation(0.1)) # Aplicando o Data Augmentation para aumento dos dados, nesse caso rotação da imagem
model.add(keras.layers.RandomTranslation(height_factor=0.1, width_factor=0.1)) # Aplicando o Data Augmentation para aumento dos dados, nesse caso translação da imagem
model.add(keras.layers.RandomZoom(0.1)) # Aplicando o Data Augmentation para aumento dos dados, nesse caso zoom na imagem
model.add(keras.layers.RandomFlip('horizontal')) # Aplicando o Data Augmentation para aumento dos dados, nesse caso flip na imagem somente na horizontal, pois o modelo não está sendo treinando com imagens de cabeça para baixo

# Etapas de CNN (Usando como base conceitos de Image....., adaptado para um modelo menos complexo)
model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.MaxPooling2D()) # Adicionando o Max Pooling visando desconsiderar o fundo da imagem
model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.MaxPooling2D()) # Adicionando o Max Pooling visando desconsiderar o fundo da imagem
model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.Conv2D(256, (1, 1), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.MaxPooling2D()) # Adicionando o Max Pooling visando desconsiderar o fundo da imagem
model.add(keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.Conv2D(512, (1, 1), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.MaxPooling2D()) # Adicionando o Max Pooling visando desconsiderar o fundo da imagem
model.add(keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.Conv2D(512, (1, 1), activation='relu', padding='same')) # Adicionando uma camada convolucional
model.add(keras.layers.MaxPooling2D()) # Adicionando o Max Pooling visando desconsiderar o fundo da imagem

# Etapas de camadas ocultas
model.add(keras.layers.Flatten()) # Realizando a redução de dimensionalidade/achatamento
model.add(keras.layers.Dense(4096, activation='relu')) # Passando a camada de sáida
model.add(keras.layers.Dropout(0.5)) # Desligando alguns neurônios aleatóriamente para tentar reduzir o overfitting
model.add(keras.layers.Dense(4096, activation='relu')) # Passando a camada de sáida
model.add(keras.layers.Dropout(0.5)) # Desligando alguns neurônios aleatóriamente para tentar reduzir o overfitting
model.add(keras.layers.Dense(10, activation='softmax')) # Passando a camada de sáida (10 = valores de resultados possíveis (0 a 9))

model.summary() # Exibindo o resumo do treinamento
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_rotation (RandomRotation)     │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation                   │ (None, 32, 32, 3)           │               0 │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_zoom (RandomZoom)             │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_flip (RandomFlip)             │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 8, 8, 256)           │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 4, 4, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 4, 4, 512)           │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 2, 2, 512)           │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 4096)                │       2,101,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │          40,970 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 28,919,626 (110.32 MB)
#  Trainable params: 28,919,626 (110.32 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compilando o modelo

# %%
optimizer = keras.optimizers.Adam(learning_rate=1E-4) # Definindo o otimizador
loss = keras.losses.SparseCategoricalCrossentropy() # Definindo a função de busca
metric = keras.metrics.SparseCategoricalAccuracy() # Definindo a métrica a ser considerada durante o treinamento

model.compile(optimizer=optimizer, loss=loss, metrics=[metric]) # Compilando o modelo

# %% [markdown]
# ### Treinando o modelo

# %%
early_stop = keras.callbacks.EarlyStopping( # Configurando um callback que interrompe o treinamento do modelo caso o desempenho pare de melhorar, com base em métricas monitoradas
    patience = 5, # Definindo o patience, que é o número de epochs consecutivas em que a métrica monitorada pode não melhorar antes de interromper o treinamento
    verbose = 1, # Definindo o verbose para exibir a informação de quando o callback for acionado caso aconteça
    min_delta = 1E-4, # Definindo a menor diferença aceitável para considerar que houve melhora em uma métrica monitorada
    start_from_epoch = 150 # Definindo a epoch mínimo em que o early stop será executado
)

history = model.fit( # Treinando o modelo e armazenando o seu resultado em uma variável
    x_train, # Passando os valores de x de treino
    y_train, # Passando os valores de y de treino
    epochs = 300, # Definindo o número máximo de epochs, ou seja, quantas vezes o modelo passará por todo o conjunto de treino durante o ajuste
    batch_size = 256, # Definindo o batch size, que é o número de amostras processadas de uma só vez antes de atualizar os pesos do modelo
    validation_split = 0.2, # Definindo a proporção dos dados de treino que será separada para validação
    callbacks = [early_stop] # Definindo o callback com a condição de parada definida anteriormente para interromper o treinamento do modelo
)
# Out:
# Epoch 1/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 33s 129ms/step - loss: 2.2317 - sparse_categorical_accuracy: 0.1372 - val_loss: 1.9495 - val_sparse_categorical_accuracy: 0.2369
# Epoch 2/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - loss: 1.8934 - sparse_categorical_accuracy: 0.2734 - val_loss: 1.7569 - val_sparse_categorical_accuracy: 0.3536
# Epoch 3/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 1.6944 - sparse_categorical_accuracy: 0.3635 - val_loss: 1.6397 - val_sparse_categorical_accuracy: 0.4003
# Epoch 4/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 109ms/step - loss: 1.5758 - sparse_categorical_accuracy: 0.4124 - val_loss: 1.6488 - val_sparse_categorical_accuracy: 0.4070
# Epoch 5/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 1.4706 - sparse_categorical_accuracy: 0.4554 - val_loss: 1.4797 - val_sparse_categorical_accuracy: 0.4778
# Epoch 6/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 1.3979 - sparse_categorical_accuracy: 0.4844 - val_loss: 1.3372 - val_sparse_categorical_accuracy: 0.5281
# Epoch 7/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 1.3194 - sparse_categorical_accuracy: 0.5162 - val_loss: 1.3599 - val_sparse_categorical_accuracy: 0.5230
# Epoch 8/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - loss: 1.2791 - sparse_categorical_accuracy: 0.5370 - val_loss: 1.4045 - val_sparse_categorical_accuracy: 0.5105
# Epoch 9/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - loss: 1.2341 - sparse_categorical_accuracy: 0.5532 - val_loss: 1.1556 - val_sparse_categorical_accuracy: 0.5862
# Epoch 10/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - loss: 1.1903 - sparse_categorical_accuracy: 0.5725 - val_loss: 1.2886 - val_sparse_categorical_accuracy: 0.5580
# Epoch 11/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 1.1517 - sparse_categorical_accuracy: 0.5862 - val_loss: 1.1736 - val_sparse_categorical_accuracy: 0.5866
# Epoch 12/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 1.1001 - sparse_categorical_accuracy: 0.6080 - val_loss: 1.4303 - val_sparse_categorical_accuracy: 0.5289
# Epoch 13/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 1.0705 - sparse_categorical_accuracy: 0.6172 - val_loss: 1.1385 - val_sparse_categorical_accuracy: 0.6145
# Epoch 14/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 1.0389 - sparse_categorical_accuracy: 0.6283 - val_loss: 1.1103 - val_sparse_categorical_accuracy: 0.6103
# Epoch 15/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 1.0342 - sparse_categorical_accuracy: 0.6357 - val_loss: 1.0993 - val_sparse_categorical_accuracy: 0.6239
# Epoch 16/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.9970 - sparse_categorical_accuracy: 0.6467 - val_loss: 0.9761 - val_sparse_categorical_accuracy: 0.6629
# Epoch 17/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.9505 - sparse_categorical_accuracy: 0.6657 - val_loss: 1.0270 - val_sparse_categorical_accuracy: 0.6442
# Epoch 18/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.9377 - sparse_categorical_accuracy: 0.6687 - val_loss: 1.0484 - val_sparse_categorical_accuracy: 0.6473
# Epoch 19/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.9112 - sparse_categorical_accuracy: 0.6791 - val_loss: 0.9049 - val_sparse_categorical_accuracy: 0.6899
# Epoch 20/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 109ms/step - loss: 0.8993 - sparse_categorical_accuracy: 0.6823 - val_loss: 1.0138 - val_sparse_categorical_accuracy: 0.6591
# Epoch 21/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - loss: 0.8707 - sparse_categorical_accuracy: 0.6915 - val_loss: 1.0349 - val_sparse_categorical_accuracy: 0.6595
# Epoch 22/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.7021 - val_loss: 0.8969 - val_sparse_categorical_accuracy: 0.6922
# Epoch 23/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.8321 - sparse_categorical_accuracy: 0.7075 - val_loss: 0.8212 - val_sparse_categorical_accuracy: 0.7155
# Epoch 24/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.8019 - sparse_categorical_accuracy: 0.7197 - val_loss: 0.9983 - val_sparse_categorical_accuracy: 0.6737
# Epoch 25/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.7947 - sparse_categorical_accuracy: 0.7244 - val_loss: 0.9941 - val_sparse_categorical_accuracy: 0.6784
# Epoch 26/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.7813 - sparse_categorical_accuracy: 0.7260 - val_loss: 0.8663 - val_sparse_categorical_accuracy: 0.7115
# Epoch 27/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.7554 - sparse_categorical_accuracy: 0.7352 - val_loss: 0.7851 - val_sparse_categorical_accuracy: 0.7421
# Epoch 28/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.7299 - sparse_categorical_accuracy: 0.7470 - val_loss: 0.9240 - val_sparse_categorical_accuracy: 0.6991
# Epoch 29/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.7327 - sparse_categorical_accuracy: 0.7486 - val_loss: 0.9118 - val_sparse_categorical_accuracy: 0.7001
# Epoch 30/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.7173 - sparse_categorical_accuracy: 0.7527 - val_loss: 0.8388 - val_sparse_categorical_accuracy: 0.7247
# Epoch 31/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.6960 - sparse_categorical_accuracy: 0.7615 - val_loss: 0.8365 - val_sparse_categorical_accuracy: 0.7281
# Epoch 32/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.6753 - sparse_categorical_accuracy: 0.7654 - val_loss: 0.8421 - val_sparse_categorical_accuracy: 0.7217
# Epoch 33/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.6600 - sparse_categorical_accuracy: 0.7737 - val_loss: 0.7602 - val_sparse_categorical_accuracy: 0.7533
# Epoch 34/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.6468 - sparse_categorical_accuracy: 0.7761 - val_loss: 0.8797 - val_sparse_categorical_accuracy: 0.7205
# Epoch 35/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.6353 - sparse_categorical_accuracy: 0.7796 - val_loss: 0.8375 - val_sparse_categorical_accuracy: 0.7338
# Epoch 36/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.6355 - sparse_categorical_accuracy: 0.7797 - val_loss: 0.7510 - val_sparse_categorical_accuracy: 0.7489
# Epoch 37/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.6186 - sparse_categorical_accuracy: 0.7845 - val_loss: 0.7841 - val_sparse_categorical_accuracy: 0.7449
# Epoch 38/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.5934 - sparse_categorical_accuracy: 0.7937 - val_loss: 0.7053 - val_sparse_categorical_accuracy: 0.7630
# Epoch 39/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.5955 - sparse_categorical_accuracy: 0.7943 - val_loss: 0.7575 - val_sparse_categorical_accuracy: 0.7561
# Epoch 40/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.5888 - sparse_categorical_accuracy: 0.7975 - val_loss: 0.7046 - val_sparse_categorical_accuracy: 0.7705
# Epoch 41/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.5590 - sparse_categorical_accuracy: 0.8030 - val_loss: 0.7125 - val_sparse_categorical_accuracy: 0.7647
# Epoch 42/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.5430 - sparse_categorical_accuracy: 0.8116 - val_loss: 0.7516 - val_sparse_categorical_accuracy: 0.7590
# Epoch 43/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.5389 - sparse_categorical_accuracy: 0.8144 - val_loss: 0.7173 - val_sparse_categorical_accuracy: 0.7624
# Epoch 44/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.5195 - sparse_categorical_accuracy: 0.8204 - val_loss: 0.7653 - val_sparse_categorical_accuracy: 0.7620
# Epoch 45/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.5171 - sparse_categorical_accuracy: 0.8223 - val_loss: 0.7084 - val_sparse_categorical_accuracy: 0.7764
# Epoch 46/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.5169 - sparse_categorical_accuracy: 0.8218 - val_loss: 0.7289 - val_sparse_categorical_accuracy: 0.7645
# Epoch 47/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.5030 - sparse_categorical_accuracy: 0.8244 - val_loss: 0.7761 - val_sparse_categorical_accuracy: 0.7595
# Epoch 48/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.4903 - sparse_categorical_accuracy: 0.8308 - val_loss: 0.9063 - val_sparse_categorical_accuracy: 0.7304
# Epoch 49/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.4897 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.7229 - val_sparse_categorical_accuracy: 0.7706
# Epoch 50/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.4741 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.7893 - val_sparse_categorical_accuracy: 0.7572
# Epoch 51/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.4620 - sparse_categorical_accuracy: 0.8397 - val_loss: 0.6975 - val_sparse_categorical_accuracy: 0.7787
# Epoch 52/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 111ms/step - loss: 0.4451 - sparse_categorical_accuracy: 0.8475 - val_loss: 0.7423 - val_sparse_categorical_accuracy: 0.7711
# Epoch 53/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.4542 - sparse_categorical_accuracy: 0.8449 - val_loss: 0.6641 - val_sparse_categorical_accuracy: 0.7912
# Epoch 54/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.4299 - sparse_categorical_accuracy: 0.8505 - val_loss: 0.7027 - val_sparse_categorical_accuracy: 0.7797
# Epoch 55/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.4287 - sparse_categorical_accuracy: 0.8507 - val_loss: 0.7955 - val_sparse_categorical_accuracy: 0.7687
# Epoch 56/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.4076 - sparse_categorical_accuracy: 0.8594 - val_loss: 0.7519 - val_sparse_categorical_accuracy: 0.7767
# Epoch 57/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.3956 - sparse_categorical_accuracy: 0.8635 - val_loss: 0.8050 - val_sparse_categorical_accuracy: 0.7515
# Epoch 58/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.4080 - sparse_categorical_accuracy: 0.8601 - val_loss: 0.6921 - val_sparse_categorical_accuracy: 0.7898
# Epoch 59/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.4009 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.7334 - val_sparse_categorical_accuracy: 0.7798
# Epoch 60/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.3789 - sparse_categorical_accuracy: 0.8684 - val_loss: 0.7198 - val_sparse_categorical_accuracy: 0.7829
# Epoch 61/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.3774 - sparse_categorical_accuracy: 0.8703 - val_loss: 0.8263 - val_sparse_categorical_accuracy: 0.7588
# Epoch 62/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.3783 - sparse_categorical_accuracy: 0.8697 - val_loss: 0.6897 - val_sparse_categorical_accuracy: 0.7900
# Epoch 63/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.3613 - sparse_categorical_accuracy: 0.8735 - val_loss: 0.7341 - val_sparse_categorical_accuracy: 0.7827
# Epoch 64/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.3500 - sparse_categorical_accuracy: 0.8754 - val_loss: 0.6793 - val_sparse_categorical_accuracy: 0.7924
# Epoch 65/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.3570 - sparse_categorical_accuracy: 0.8747 - val_loss: 0.8039 - val_sparse_categorical_accuracy: 0.7692
# Epoch 66/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.3392 - sparse_categorical_accuracy: 0.8821 - val_loss: 0.6934 - val_sparse_categorical_accuracy: 0.7937
# Epoch 67/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.3401 - sparse_categorical_accuracy: 0.8823 - val_loss: 0.6953 - val_sparse_categorical_accuracy: 0.7959
# Epoch 68/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.3296 - sparse_categorical_accuracy: 0.8867 - val_loss: 0.7167 - val_sparse_categorical_accuracy: 0.7889
# Epoch 69/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.3247 - sparse_categorical_accuracy: 0.8871 - val_loss: 0.7101 - val_sparse_categorical_accuracy: 0.7957
# Epoch 70/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.3135 - sparse_categorical_accuracy: 0.8913 - val_loss: 0.7766 - val_sparse_categorical_accuracy: 0.7878
# Epoch 71/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.3178 - sparse_categorical_accuracy: 0.8902 - val_loss: 0.7664 - val_sparse_categorical_accuracy: 0.7895
# Epoch 72/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.3096 - sparse_categorical_accuracy: 0.8953 - val_loss: 0.8035 - val_sparse_categorical_accuracy: 0.7842
# Epoch 73/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.2959 - sparse_categorical_accuracy: 0.8978 - val_loss: 0.6980 - val_sparse_categorical_accuracy: 0.7993
# Epoch 74/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.3047 - sparse_categorical_accuracy: 0.8929 - val_loss: 0.7538 - val_sparse_categorical_accuracy: 0.7924
# Epoch 75/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.2849 - sparse_categorical_accuracy: 0.9020 - val_loss: 0.7334 - val_sparse_categorical_accuracy: 0.7940
# Epoch 76/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.2811 - sparse_categorical_accuracy: 0.9032 - val_loss: 0.7439 - val_sparse_categorical_accuracy: 0.7958
# Epoch 77/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.2728 - sparse_categorical_accuracy: 0.9030 - val_loss: 0.7650 - val_sparse_categorical_accuracy: 0.7936
# Epoch 78/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.2755 - sparse_categorical_accuracy: 0.9065 - val_loss: 0.7400 - val_sparse_categorical_accuracy: 0.8010
# Epoch 79/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.2642 - sparse_categorical_accuracy: 0.9081 - val_loss: 0.7644 - val_sparse_categorical_accuracy: 0.7933
# Epoch 80/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.2639 - sparse_categorical_accuracy: 0.9063 - val_loss: 0.7639 - val_sparse_categorical_accuracy: 0.7966
# Epoch 81/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.2466 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.7280 - val_sparse_categorical_accuracy: 0.8018
# Epoch 82/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - loss: 0.2514 - sparse_categorical_accuracy: 0.9139 - val_loss: 0.7747 - val_sparse_categorical_accuracy: 0.7940
# Epoch 83/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.2619 - sparse_categorical_accuracy: 0.9096 - val_loss: 0.7622 - val_sparse_categorical_accuracy: 0.7984
# Epoch 84/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.2411 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.7382 - val_sparse_categorical_accuracy: 0.8047
# Epoch 85/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.2355 - sparse_categorical_accuracy: 0.9190 - val_loss: 0.7097 - val_sparse_categorical_accuracy: 0.8063
# Epoch 86/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.2339 - sparse_categorical_accuracy: 0.9195 - val_loss: 0.7734 - val_sparse_categorical_accuracy: 0.7981
# Epoch 87/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.2315 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.7611 - val_sparse_categorical_accuracy: 0.8021
# Epoch 88/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.2233 - sparse_categorical_accuracy: 0.9208 - val_loss: 0.7228 - val_sparse_categorical_accuracy: 0.8055
# Epoch 89/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 0.2255 - sparse_categorical_accuracy: 0.9234 - val_loss: 0.7700 - val_sparse_categorical_accuracy: 0.7995
# Epoch 90/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.2222 - sparse_categorical_accuracy: 0.9231 - val_loss: 0.8297 - val_sparse_categorical_accuracy: 0.7900
# Epoch 91/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.2145 - sparse_categorical_accuracy: 0.9243 - val_loss: 0.7750 - val_sparse_categorical_accuracy: 0.7976
# Epoch 92/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.2128 - sparse_categorical_accuracy: 0.9264 - val_loss: 0.7814 - val_sparse_categorical_accuracy: 0.8017
# Epoch 93/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.2074 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.7662 - val_sparse_categorical_accuracy: 0.7992
# Epoch 94/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.2082 - sparse_categorical_accuracy: 0.9295 - val_loss: 0.8194 - val_sparse_categorical_accuracy: 0.7948
# Epoch 95/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.1963 - sparse_categorical_accuracy: 0.9329 - val_loss: 0.8009 - val_sparse_categorical_accuracy: 0.8015
# Epoch 96/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.2083 - sparse_categorical_accuracy: 0.9276 - val_loss: 0.8123 - val_sparse_categorical_accuracy: 0.7999
# Epoch 97/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.2071 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.8234 - val_sparse_categorical_accuracy: 0.7974
# Epoch 98/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.1921 - sparse_categorical_accuracy: 0.9336 - val_loss: 0.8773 - val_sparse_categorical_accuracy: 0.7860
# Epoch 99/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.1932 - sparse_categorical_accuracy: 0.9325 - val_loss: 0.8598 - val_sparse_categorical_accuracy: 0.8018
# Epoch 100/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.1788 - sparse_categorical_accuracy: 0.9364 - val_loss: 0.8276 - val_sparse_categorical_accuracy: 0.7969
# Epoch 101/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1754 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.8540 - val_sparse_categorical_accuracy: 0.8030
# Epoch 102/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1885 - sparse_categorical_accuracy: 0.9337 - val_loss: 0.7849 - val_sparse_categorical_accuracy: 0.8129
# Epoch 103/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.1894 - sparse_categorical_accuracy: 0.9367 - val_loss: 0.8551 - val_sparse_categorical_accuracy: 0.7941
# Epoch 104/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.1747 - sparse_categorical_accuracy: 0.9376 - val_loss: 0.8015 - val_sparse_categorical_accuracy: 0.8043
# Epoch 105/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.1826 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.9068 - val_sparse_categorical_accuracy: 0.7905
# Epoch 106/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.1691 - sparse_categorical_accuracy: 0.9428 - val_loss: 0.8001 - val_sparse_categorical_accuracy: 0.8089
# Epoch 107/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.1669 - sparse_categorical_accuracy: 0.9430 - val_loss: 0.8602 - val_sparse_categorical_accuracy: 0.7943
# Epoch 108/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.1682 - sparse_categorical_accuracy: 0.9429 - val_loss: 0.8432 - val_sparse_categorical_accuracy: 0.7993
# Epoch 109/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.1607 - sparse_categorical_accuracy: 0.9434 - val_loss: 0.8503 - val_sparse_categorical_accuracy: 0.8003
# Epoch 110/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.1749 - sparse_categorical_accuracy: 0.9399 - val_loss: 0.8075 - val_sparse_categorical_accuracy: 0.8069
# Epoch 111/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1633 - sparse_categorical_accuracy: 0.9442 - val_loss: 0.8424 - val_sparse_categorical_accuracy: 0.8034
# Epoch 112/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.1664 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.7752 - val_sparse_categorical_accuracy: 0.8140
# Epoch 113/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 110ms/step - loss: 0.1602 - sparse_categorical_accuracy: 0.9436 - val_loss: 0.8273 - val_sparse_categorical_accuracy: 0.8118
# Epoch 114/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.1600 - sparse_categorical_accuracy: 0.9451 - val_loss: 0.7815 - val_sparse_categorical_accuracy: 0.8075
# Epoch 115/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 0.1551 - sparse_categorical_accuracy: 0.9478 - val_loss: 0.8830 - val_sparse_categorical_accuracy: 0.7917
# Epoch 116/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1604 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.8594 - val_sparse_categorical_accuracy: 0.7961
# Epoch 117/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1507 - sparse_categorical_accuracy: 0.9484 - val_loss: 0.7846 - val_sparse_categorical_accuracy: 0.8076
# Epoch 118/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1399 - sparse_categorical_accuracy: 0.9521 - val_loss: 0.8638 - val_sparse_categorical_accuracy: 0.7994
# Epoch 119/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9479 - val_loss: 0.8786 - val_sparse_categorical_accuracy: 0.8019
# Epoch 120/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.1481 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.8242 - val_sparse_categorical_accuracy: 0.8125
# Epoch 121/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1556 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.8348 - val_sparse_categorical_accuracy: 0.8049
# Epoch 122/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.1326 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.9219 - val_sparse_categorical_accuracy: 0.8061
# Epoch 123/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.1359 - sparse_categorical_accuracy: 0.9533 - val_loss: 0.8546 - val_sparse_categorical_accuracy: 0.8050
# Epoch 124/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.1473 - sparse_categorical_accuracy: 0.9495 - val_loss: 0.8712 - val_sparse_categorical_accuracy: 0.8056
# Epoch 125/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.1379 - sparse_categorical_accuracy: 0.9513 - val_loss: 0.8443 - val_sparse_categorical_accuracy: 0.8094
# Epoch 126/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1438 - sparse_categorical_accuracy: 0.9502 - val_loss: 0.8021 - val_sparse_categorical_accuracy: 0.8124
# Epoch 127/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.1322 - sparse_categorical_accuracy: 0.9559 - val_loss: 0.8740 - val_sparse_categorical_accuracy: 0.8062
# Epoch 128/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - loss: 0.1330 - sparse_categorical_accuracy: 0.9541 - val_loss: 0.8752 - val_sparse_categorical_accuracy: 0.8038
# Epoch 129/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.1248 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.8955 - val_sparse_categorical_accuracy: 0.8015
# Epoch 130/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.1352 - sparse_categorical_accuracy: 0.9549 - val_loss: 0.9281 - val_sparse_categorical_accuracy: 0.7921
# Epoch 131/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1314 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.8156 - val_sparse_categorical_accuracy: 0.8095
# Epoch 132/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.1259 - sparse_categorical_accuracy: 0.9565 - val_loss: 0.8614 - val_sparse_categorical_accuracy: 0.8055
# Epoch 133/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1225 - sparse_categorical_accuracy: 0.9579 - val_loss: 0.8625 - val_sparse_categorical_accuracy: 0.8032
# Epoch 134/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.1346 - sparse_categorical_accuracy: 0.9544 - val_loss: 0.8009 - val_sparse_categorical_accuracy: 0.8138
# Epoch 135/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1207 - sparse_categorical_accuracy: 0.9596 - val_loss: 0.8317 - val_sparse_categorical_accuracy: 0.8106
# Epoch 136/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.1205 - sparse_categorical_accuracy: 0.9588 - val_loss: 0.8792 - val_sparse_categorical_accuracy: 0.8097
# Epoch 137/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 0.1250 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.8620 - val_sparse_categorical_accuracy: 0.8088
# Epoch 138/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.1219 - sparse_categorical_accuracy: 0.9575 - val_loss: 0.8914 - val_sparse_categorical_accuracy: 0.8020
# Epoch 139/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.1220 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.8930 - val_sparse_categorical_accuracy: 0.8031
# Epoch 140/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 0.1115 - sparse_categorical_accuracy: 0.9600 - val_loss: 0.8793 - val_sparse_categorical_accuracy: 0.8058
# Epoch 141/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.1192 - sparse_categorical_accuracy: 0.9599 - val_loss: 0.8899 - val_sparse_categorical_accuracy: 0.8103
# Epoch 142/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1095 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.9681 - val_sparse_categorical_accuracy: 0.7879
# Epoch 143/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.1061 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.8793 - val_sparse_categorical_accuracy: 0.8037
# Epoch 144/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 0.1134 - sparse_categorical_accuracy: 0.9612 - val_loss: 0.8728 - val_sparse_categorical_accuracy: 0.8105
# Epoch 145/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 0.1100 - sparse_categorical_accuracy: 0.9627 - val_loss: 0.9069 - val_sparse_categorical_accuracy: 0.8035
# Epoch 146/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.1098 - sparse_categorical_accuracy: 0.9631 - val_loss: 0.8618 - val_sparse_categorical_accuracy: 0.8162
# Epoch 147/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.1039 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.9014 - val_sparse_categorical_accuracy: 0.8063
# Epoch 148/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 0.1246 - sparse_categorical_accuracy: 0.9578 - val_loss: 0.9171 - val_sparse_categorical_accuracy: 0.8039
# Epoch 149/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 112ms/step - loss: 0.1115 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.8419 - val_sparse_categorical_accuracy: 0.8090
# Epoch 150/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 111ms/step - loss: 0.1038 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.9253 - val_sparse_categorical_accuracy: 0.7997
# Epoch 151/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.1035 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.8583 - val_sparse_categorical_accuracy: 0.8156
# Epoch 152/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.1093 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.8760 - val_sparse_categorical_accuracy: 0.8015
# Epoch 153/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 111ms/step - loss: 0.1041 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.8640 - val_sparse_categorical_accuracy: 0.8093
# Epoch 154/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1007 - sparse_categorical_accuracy: 0.9658 - val_loss: 0.8317 - val_sparse_categorical_accuracy: 0.8158
# Epoch 155/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1093 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.8766 - val_sparse_categorical_accuracy: 0.7934
# Epoch 156/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.0981 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.8401 - val_sparse_categorical_accuracy: 0.8178
# Epoch 157/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 0.1114 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.8610 - val_sparse_categorical_accuracy: 0.8038
# Epoch 158/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.0966 - sparse_categorical_accuracy: 0.9669 - val_loss: 0.8732 - val_sparse_categorical_accuracy: 0.8090
# Epoch 159/300
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 0.0970 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.9349 - val_sparse_categorical_accuracy: 0.8033
# Epoch 159: early stopping

# %% [markdown]
# ### Fazendo o evaluate do modelo

# %%
model.evaluate(x_test, y_test) # Fazendo o evaluate do modelo
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.9699 - sparse_categorical_accuracy: 0.7975
# [0.994256854057312, 0.7926999926567078]

# %% [markdown]
# ### Verificando possíveis condições de overfitting

# %%
plt.plot(history.history['loss'], label='loss') # Plotando os valores de treino
plt.plot(history.history['val_loss'], label='val_loss') # Plotando os valores de validação
plt.legend() # Exibindo as legendas
plt.show() # Exibindo o gráfico

# %%
plt.plot(history.history['sparse_categorical_accuracy'], label='accuracy') # Plotando os valores de treino
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy') # Plotando os valores de validação
plt.legend() # Exibindo as legendas
plt.show() # Exibindo o gráfico

# %% [markdown]
# Nesse cenário, após a aplicação do pré processamento de Data Augmentation, os índicios de overfitting não aparecem mais, deixando assim o modelo pronto para ser utilizado com os dados reais.

# %% [markdown]
# ### Fazendo o predict do modelo com uma amostra dos dados

# %%
fig, axs = plt.subplots(figsize=(12,6), nrows=4, ncols=5) # Definindo o tamanho da figura para exibir os gráficos

for i, ax in enumerate(axs.flat): # Criando uma estrutura de repetição para percorrer cada valor de x e plotar em um gráfico
    ax.imshow(x_test[i]) # Plotando a imagem em um gráfico em escala de cinza
    ax.set_title(f'Class: {class_names[y_test[i][0]]}', size=10, pad=15) # Definindo o título do gráfico
    ax.axis('off') # Desativando os títulos dos eixos
    pred = model.predict(np.expand_dims(x_test[i], axis=0), verbose=0)[0] # Armazenando a previsão do modelo em uma variável
    ax.text( # Adicionando um texto com a previsão do modelo
        16, # Definindo a posição horizontal
        -4, # Definindo a posição vertical
        f'Predict: {class_names[pred.argmax()]} - {pred.max():.1%}', # Definindo o conteúdo do texto
        color='green' if pred.argmax() == y_test[i] else 'red', # Definindo a cor do texto, variando de acordo com a previsão certa ou errada
        verticalalignment = 'center', # Definindo o alinhamento vertical
        horizontalalignment = 'center', # Definindo o alinhamento horizontal
    )

fig.subplots_adjust(hspace=0.6) # Ajustando o espaço entre cada subfigura

plt.show() # Exibindo os gráficos
